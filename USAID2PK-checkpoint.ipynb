# %%
import os
current_dir = os.getcwd()
print("Current directory:", current_dir)
# Out:
# Current directory: C:\Users\R

# %%
new_dir = '\\Users\R\Downloads\data'
os.chdir(new_dir)

# %%
updated_dir = os.getcwd()
print("Updated directory:", updated_dir)
# Out:
# Updated directory: C:\Users\R\Downloads\data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import ipywidgets as widgets
import plotly.express as px
from IPython.display import display
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.io as pio
# Load the data
data = pd.read_csv('filtered_US_aidpk.csv')

# Display the first few rows
data.head()
# Out:
#    Fiscal Year         US Category Name  \
# 0         2023  Humanitarian Assistance
# 1         2023     Economic Development
# 2         2023                   Health
# 3         2023  Humanitarian Assistance
# 4         2023          Program Support
#
#                                       US Sector Name  Current Dollar Amount  \
# 0               Protection, Assistance and Solutions               25076538
# 1                                        Agriculture                8000000
# 2  Pandemic Influenza and Other Emerging Threats ...                6100451
# 3               Protection, Assistance and Solutions                5157625
# 4                        Direct Administrative Costs                4044723
#
#                                        Activity Name  \
# 0                          Emergency Food Assistance
# 1                          Emergency food assistance
# 2  Integrated Health Systems Strengthening and Se...
# 3  Humanitarian Assistance - provide rapid respon...
# 4                             USAID Pay and Benefits
#
#   Implementing Partner Category Name Implementing Partner Sub-category ID  \
# 0                       Multilateral        Multilateral - United Nations
# 1                       Multilateral        Multilateral - United Nations
# 2                                NGO                  NGO - United States
# 3                                NGO                  NGO - United States
# 4                         Government           Government - United States
#
#                            Implementing Partner Name
# 0                                 World Food Program
# 1                  Food and Agriculture Organisation
# 2                            John Snow International
# 3                       NGO - United States Redacted
# 4  U.S. Government - U.S. Agency for Internationa...

# %%
# Create a sorted list of years
years = sorted(data['Fiscal Year'].unique())

# Create a dropdown widget
year_widget = widgets.Dropdown(
    options=years,
    value=years[0],
    description='Year:',
    disabled=False,
)

# Function to update the chart
def update_chart(year):
    # Filter data for selected year
    data_year = data[data['Fiscal Year'] == year]
    
    # Group by category and sum dollar amounts
    category_sums = data_year.groupby('US Category Name')['Current Dollar Amount'].sum()
    
    # Create bar chart
    plt.figure(figsize=(10, 6))
    plt.bar(category_sums.index, category_sums.values)
    plt.xlabel('Category')
    plt.ylabel('Total Dollar Amount')
    plt.title(f'Total Aid Amount by Category in {year}')
    plt.xticks(rotation=90)
    plt.show()

# Display the widget and chart
display(year_widget)
_ = widgets.interact(update_chart, year=year_widget)
# Out:
# Dropdown(description='Year:', options=(2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,…
# interactive(children=(Dropdown(description='Year:', options=(2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2…

# %%
# Total aid given each year
fig1 = px.bar(data, x='Fiscal Year', y='Current Dollar Amount', 
             hover_data=['US Category Name'],  # Add this line
              labels={'Current Dollar Amount':'Dollar Amount (in billions $)',
                      'Fiscal Year': 'Year' , 'US Category Name': 'Ca'},
              title='Total US Aid Given Each Year 2000-2023',
              template='plotly_white')
fig1.update_traces(marker_color='skyblue')
fig1.update_layout(yaxis_tickprefix = '$', yaxis_ticksuffix = 'B')
fig1.show()

# Distribution of aid among different categories
data_category = data.groupby('US Category Name')['Current Dollar Amount'].sum().reset_index()
fig2 = px.pie(data_category, names='US Category Name', values='Current Dollar Amount', 
             labels={'US Category Name': 'Category'},
              title='Distribution of Aid Among Categories',
              template='plotly_white')
fig2.show()

# Top 10 sectors receiving aid
data_sector = data.groupby('US Sector Name')['Current Dollar Amount'].sum().nlargest(10).reset_index()
fig3 = px.bar(data_sector, y='US Sector Name', x='Current Dollar Amount', 
              labels={'Current Dollar Amount':'Total Dollar Amount (in billions)',
                      'US Sector Name': 'Sector'},
              title='Top 10 Sectors Receiving Aid',
              template='plotly_white', orientation='h')
fig3.update_traces(marker_color='skyblue')
fig3.update_layout(xaxis_tickprefix = '$', xaxis_ticksuffix = 'B')
fig3.show()
# Out:
# <div>                            <div id="e2eb92f1-d9f2-4287-ad03-e98005157677" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2eb92f1-d9f2-4287-ad03-e98005157677")) {                    Plotly.newPlot(                        "e2eb92f1-d9f2-4287-ad03-e98005157677",                        [{"alignmentgroup":"True","customdata":[["Humanitarian Assistance"],["Economic Development"],["Health"],["Humanitarian Assistance"],["Program Support"],["Humanitarian Assistance"],["Democracy, Human Rights, and Governance"],["Economic Development"],["Democracy, Human Rights, and Governance"],["Humanitarian Assistance"],["Economic Development"],["Education and Social Services"],["Economic Development"],["Education and Social Services"],["Peace and Security"],["Economic Development"],["Economic Development"],["Economic Development"],["Peace and Security"],["Education and Social Services"],["Health"],["Humanitarian Assistance"],["Economic Development"],["Program Support"],["Economic Development"],["Peace and Security"],["Economic Development"],["Peace and Security"],["Economic Development"],["Humanitarian Assistance"],["Democracy, Human Rights, and Governance"],["Economic Development"],["Humanitarian Assistance"],["Democracy, Human Rights, and Governance"],["Health"],["Economic Development"],["Economic Development"],["Economic Development"],["Democracy, Human Rights, and Governance"],["Economic Development"],["Democracy, Human Rights, and Governance"],["Humanitarian Assistance"],["Education and Social Services"],["Democracy, Human Rights, and Governance"],["Program Support"],["Democracy, Human Rights, and Governance"],["Peace and Security"],["Program Support"],["Economic Development"],["Program Support"],["Economic Development"],["Humanitarian Assistance"],["Peace and Security"],["Program Support"],["Economic Development"],["Economic Development"],["Education and Social Services"],["Humanitarian Assistance"],["Economic Development"],["Peace and Security"],["Health"],["Democracy, Human Rights, and Governance"],["Program Support"],["Program Support"],["Education and Social Services"],["Economic Development"],["Health"],["Peace and Security"],["Health"],["Program Support"],["Program Support"],["Economic Development"],["Education and Social Services"],["Economic Development"],["Peace and Security"],["Economic Development"],["Economic Development"],["Health"],["Humanitarian Assistance"],["Education and Social Services"],["Economic Development"],["Health"],["Peace and Security"],["Program Support"],["Health"],["Health"],["Peace and Security"],["Education and Social Services"],["Economic Development"],["Economic Development"],["Education and Social Services"],["Peace and Security"],["Democracy, Human Rights, and Governance"],["Program Support"],["Democracy, Human Rights, and Governance"],["Health"],["Economic Development"],["Program Support"],["Peace and Security"],["Humanitarian Assistance"],["Program Support"],["Humanitarian Assistance"],["Program Support"],["Economic Development"],["Health"],["Program Support"],["Program Support"],["Democracy, Human Rights, and Governance"],["Economic Development"],["Health"],["Program Support"],["Program Support"],["Democracy, Human Rights, and Governance"],["Economic Development"],["Health"],["Program Support"],["Humanitarian Assistance"],["Education and Social Services"],["Health"],["Program Support"],["Humanitarian Assistance"],["Education and Social Services"],["Program Support"],["Economic Development"],["Program Support"],["Peace and Security"],["Program Support"],["Democracy, Human Rights, and Governance"],["Program Support"],["Program Support"],["Program Support"],["Program Support"],["Education and Social Services"],["Health"],["Economic Development"],["Program Support"] ...
# <div>                            <div id="37b95a2f-6ee9-4b62-a1b8-f24fe9a26efa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37b95a2f-6ee9-4b62-a1b8-f24fe9a26efa")) {                    Plotly.newPlot(                        "37b95a2f-6ee9-4b62-a1b8-f24fe9a26efa",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Category=%{label}<br>Current Dollar Amount=%{value}<extra></extra>","labels":["Democracy, Human Rights, and Governance","Economic Development","Education and Social Services","Environment","Health","Humanitarian Assistance","Multi-sector","Peace and Security","Program Support"],"legendgroup":"","name":"","showlegend":true,"values":[1611505602,2609771867,1654856529,2336320,1154576163,3349153291,388479244,5889993843,759730346],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"a ...
# <div>                            <div id="9a80b3b8-689b-441d-9181-05e809e8b61a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a80b3b8-689b-441d-9181-05e809e8b61a")) {                    Plotly.newPlot(                        "9a80b3b8-689b-441d-9181-05e809e8b61a",                        [{"alignmentgroup":"True","hovertemplate":"Total Dollar Amount (in billions)=%{x}<br>Sector=%{y}<extra></extra>","legendgroup":"","marker":{"color":"skyblue","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[5198219402,3129055621,1508773549,904252405,882891829,759730346,614039717,499517215,462412991,387351336],"xaxis":"x","y":["Stabilization Operations and Security Sector Reform","Protection, Assistance and Solutions","Infrastructure","Rule of Law and Human Rights","Basic Education","Direct Administrative Costs","Agriculture","Good Governance","Social Assistance","Debt Relief"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"his ...

# %%
fig2.write_html("your_plot.html")

# %%
# Group the data by year and category, then reset the index
data_grouped = data.groupby(['Fiscal Year', 'US Category Name'])['Current Dollar Amount'].sum().reset_index()

# Create a list of unique years
years = data_grouped['Fiscal Year'].unique()

# Create a figure
fig4 = go.Figure()

# Add one trace for each year
for year in years:
    fig4.add_trace(
        go.Pie(
            labels=data_grouped[data_grouped['Fiscal Year'] == year]['US Category Name'],
            values=data_grouped[data_grouped['Fiscal Year'] == year]['Current Dollar Amount'] / 1e6,  # Convert to billions
            name=str(year),
            visible=False if year != min(years) else True,  # Only the first year is visible initially
            hoverinfo='label+value+percent',
            textinfo='label+value',
            texttemplate='%{label}<br>$%{value:.2f}mn',
            hole=0.7
        )
    )

# Add a dropdown menu to select the year
buttons = []
for i, year in enumerate(years):
    visibility = [False] * len(years)
    visibility[i] = True
    button = dict(
        label = str(year),
        method = 'update',
        args = [{'visible': visibility}]
    )
    buttons.append(button)

fig4.update_layout(

    margin=dict(
       
        t=130,  # top margin
        pad=100  # padding
    ),
 
    updatemenus=[
        dict(
            type="dropdown",
            direction="down",
            buttons=buttons,
            showactive=True,
            xanchor="right",
            yanchor="bottom",
            
        )
    ],
    title='US AID to Pakistan -Distribution of Aid Among Categories 2001-2023',
    template='plotly_white'
)

fig4.show()
# Out:
# <div>                            <div id="ce2a1f83-d1aa-4723-b6d7-a959e305624c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce2a1f83-d1aa-4723-b6d7-a959e305624c")) {                    Plotly.newPlot(                        "ce2a1f83-d1aa-4723-b6d7-a959e305624c",                        [{"hole":0.7,"hoverinfo":"label+value+percent","labels":["Democracy, Human Rights, and Governance","Environment","Health","Humanitarian Assistance","Peace and Security","Program Support"],"name":"2001","textinfo":"label+value","texttemplate":"%{label}<br>$%{value:.2f}mn","values":[80.040943,0.018033,5.649844,5.293804,0.143,0.755892],"visible":true,"type":"pie"},{"hole":0.7,"hoverinfo":"label+value+percent","labels":["Democracy, Human Rights, and Governance","Economic Development","Education and Social Services","Environment","Health","Humanitarian Assistance","Peace and Security","Program Support"],"name":"2002","textinfo":"label+value","texttemplate":"%{label}<br>$%{value:.2f}mn","values":[92.968124,12.009709,2.9583,0.014446,5.934394,606.391544,76.464,1.327272],"visible":false,"type":"pie"},{"hole":0.7,"hoverinfo":"label+value+percent","labels":["Democracy, Human Rights, and Governance","Economic Development","Education and Social Services","Environment","Health","Humanitarian Assistance","Multi-sector","Peace and Security","Program Support"],"name":"2003","textinfo":"label+value","texttemplate":"%{label}<br>$%{value:.2f}mn","values":[33.702723,21.710584,6.878503,0.02807,12.327212,7.883571,187.351336,264.173125,2.839415],"visible":false,"type":"pie"},{"hole":0.7,"hoverinfo":"label+value+percent","labels":["Democracy, Human Rights, and Governance","Economic Development","Education and Social Services","Environment","Health","Humanitarian Assistance","Multi-sector","Peace and Security","Program Support"],"name":"2004","textinfo":"label+value","texttemplate":"%{label}<br>$%{value:.2f}mn","values":[4.024415,1.950786,23.013794,0.160601,18.223465,11.453053,200.0,86.579929,0.969612],"visible":false,"type":"pie"},{"hole":0.7,"hoverinfo":"label+value+percent","labels":["Democracy, Human Rights, and Governance","Economic Development","Education and Social Services","Environment","Health","Humanitarian Assistance","Peace and Security","Program Support"],"name":"2005","textinfo":"label+value","texttemplate":"%{label}<br>$%{value:.2f}mn","values":[27.109368,11.678871,24.657746,0.032887,30.874284,204.173907,329.793206,1.371281],"visible":false,"type":"pie"},{"hole":0.7,"hoverinfo":"label+value+percent","labels":["Democracy, Human Rights, and Governance","Economic Development","Education and Social Services","Environment","Health","Humanitarian Assistance","Peace and Security","Program Support"],"name":"2006","textinfo":"label+value","texttemplate":"%{label}<br>$%{value:.2f}mn","values":[10.093653,21.869355,48.656698,0.077953,43.525662,359.121014,332.138083,2.274322],"visible":false,"type":"pie"},{"hole":0.7,"hoverinfo":"label+value+percent","labels":["Democracy, Human Rights, and Governance","Economic Development","Education and Social Services","Environment","Health","Humanitarian Assistance","Multi-sector","Peace and Security","Program Support"],"name":"2007","textinfo":"label+value","texttemplate":"%{label}<br>$%{value:.2f}mn","values":[27.768056,36.155576,99.106376,0.050035,140.443533,82.701045,0.178499,355.890867,10.047142],"visible":false,"type":"pie"},{"hole":0.7,"hoverinfo":"label+value+percent","labels":["Democracy, Human Rights, and Governance","Economic Development","Education and Social Services","Environment","Health","Humanitarian Assistance","Peace and Security","Program Support"],"name":"2008","textinfo":"label+value","texttemplate":"%{label}<br>$%{value:.2f}mn","values":[64.549432,92.097317,20.584874,0. ...

# %%
fig.write_html("syour_plot.html")

# %%
from IPython.display import display, clear_output

# Create a year slider
year_slider = widgets.IntSlider(min=data['Fiscal Year'].min(), max=data['Fiscal Year'].max(), step=1, description='Year')

# Create output widgets for the figures
output_fig1 = widgets.Output()
output_fig2 = widgets.Output()
output_fig3 = widgets.Output()
output_fig4 = widgets.Output()

def display_figures(year):
    with output_fig1:
        clear_output(wait=True)  # Clear previous figure
        fig1.show()

    with output_fig2:
        clear_output(wait=True)  # Clear previous figure
        fig2.show()

    with output_fig3:
        clear_output(wait=True)  # Clear previous figure
        fig3.show()

    with output_fig4:
        clear_output(wait=True)  # Clear previous figure

        # Filter data for the selected year
        data_year = data[data['Fiscal Year'] == year]

        # Group the data by category, then reset the index
        data_grouped = data_year.groupby('US Category Name')['Current Dollar Amount'].sum().reset_index()

        # Create the pie chart
        fig = go.Figure(
            data=[go.Pie(
                labels=data_grouped['US Category Name'],
                values=data_grouped['Current Dollar Amount'] / 1e9,  # Convert to billions
                hoverinfo='label+value+percent',
                textinfo='label+value',
                texttemplate='%{label}<br>$%{value:.2f}B',
                hole=0.7
            )]
        )

        fig.update_layout(
            title='US Aid to Pakistan - Distribution of Aid Among Categories in {}'.format(year),
            template='plotly_white'
        )

        fig.show()

# Call the function with the minimum year to display the figures initially
display_figures(data['Fiscal Year'].min())

# Create a widget container to display the slider and the figures
widget_container = widgets.VBox([year_slider, output_fig1, output_fig2, output_fig3, output_fig4])

# Display the widget container
display(widget_container)

# Connect the slider to the function
year_slider.observe(lambda change: display_figures(change.new), 'value')
# Out:
# VBox(children=(IntSlider(value=2001, description='Year', max=2023, min=2001), Output(), Output(), Output(), Ou…

# %%
display_figures.write_html('figure.html')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 display_figures.write_html('figure.html')
#
# AttributeError: 'function' object has no attribute 'write_html'

# %%
pio.write_html(dashboard, 'dashboard.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 pio.write_html(dashboard, 'dashboard.html')
#
# NameError: name 'dashboard' is not defined
